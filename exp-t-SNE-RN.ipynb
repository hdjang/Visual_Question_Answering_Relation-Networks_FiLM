# %%
# %matplotlib inline
from utils import draw_tSNE

# %%
digits = datasets.load_digits()
X = digits.data[:500]   # (N,embed-dim)
Y = digits.target[:500] # (N,label-dim)

# %%
draw_tSNE(X,Y,digits.target_names)
